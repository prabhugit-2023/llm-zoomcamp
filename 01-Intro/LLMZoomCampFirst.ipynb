# %%
import openai
from openai import OpenAI
import os

# API key should be set in environment variable OPENAI_API_KEY
client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))

response = client.chat.completions.create(
    model='gpt-4o',
    messages=[{"role":"user","content":"It is my first OpenAI API Call on my own subscription"}]
)
response.choices[0].message.content
# Out:
# 'That\'s exciting! Making your first OpenAI API call is a significant step. Here\'s a general overview of how you can make a call to the OpenAI API using Python. You\'ll need the `openai` Python package to get started.\n\nHere\'s a step-by-step guide:\n\n1. **Install the OpenAI Python Package**: If you haven\'t already installed it, you can do so using pip:\n\n   ```bash\n   pip install openai\n   ```\n\n2. **Obtain Your API Key**: Log into your OpenAI account and go to the API section to find your API key, which you\'ll need to authenticate your requests.\n\n3. **Write Your Script**: Use the following example as a basis for your first API call. This example demonstrates a basic GPT-3.5 call to generate text:\n\n   ```python\n   import openai\n\n   openai.api_key = \'your-api-key-here\'  # Replace with your own API key\n\n   response = openai.Completion.create(\n       engine="text-davinci-003",  # Choose the model you want to use\n       prompt="Translate the following English text to French: \'Hello, how are you?\'",\n       max_tokens=60,  # You can adjust this value as needed\n       temperature=0.5  # Controls the randomness of the output\n   )\n\n   print(response.choices[0].text.strip())\n   ```\n\n4. **Run Your Script**: Execute your Python script to make the API call. If successful, it should return the output based on your prompt.\n\n5. **Handle Errors and Issues**: Be prepared to handle any potential errors like authentication issues, rate limits, or invalid inputs.\n\nRemember, you are billed based on usage, so keep an eye on your used tokens, especially during testing or development phases, to avoid unexpected charges. You can set up usage alerts or limits in your OpenAI account settings to help manage this.'
